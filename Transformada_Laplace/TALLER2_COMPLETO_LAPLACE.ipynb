# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Transformada_Laplace/TALLER2_COMPLETO_LAPLACE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Taller 2 - LAPLACE**
# #**Hamerson Joel Piarpuezan Piarpuezan**
# #**1004531735**

# %% [markdown]
# #**Punto 1**
# #Consultar y realizar los ejercicios propuestos en el cuaderno de Colab Convolucion.
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/2_SLIT/2_Convolucion.ipynb

# %% [markdown]
# #**Punto 2**
# #Consultar y realizar los ejercicios propuestos en el cuaderno de Colab Respuesta impulso.
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/2_SLIT/1_Respuesta_Impulso.ipynb

# %% [markdown]
# #**Punto 3**
#
# Demostración de si lo siguientes sistemas son y = H{x} son sistemas lineales e invariantes en el tiempo.(SLIT):

# %% [markdown]
# SISTEMA 1: $y[n] = \frac{x[n]}{3} + 2x[n-1] - y[n-1]$$y[n] = \frac{x[n]}{3} + 2x[n-1] - y[n-1]$

# %% [markdown]
# SISTEMA 2: $y[n] = \sum_{k=-\infty}^{n} x^2[k]$$y[n] = \sum_{k=-\infty}^{n} x^2[k]$

# %% [markdown]
# SISTEMA 3: $y[n] = \mathrm{median}(x[n-1],\, x[n],\, x[n+1])$$y[n] = \mathrm{median}(x[n-1],\, x[n],\, x[n+1])$

# %% [markdown]
# SISTEMA 4: $y(t) = A \cdot x(t) + B \qquad \text{con } A, B \in \mathbb{R}$$y(t) = A \cdot x(t) + B \qquad \text{con } A, B \in \mathbb{R}$

# %% [markdown]
# #La demostracion en el siguiente enlace : https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Taller2-Laplace.pdf

# %% [markdown]
# ##Simulación en Python

# %% [markdown]
# ##SISTEMA 1 con realimentación:#
# $y[n] = \frac{x[n]}{3} + 2x[n-1] - y[n-1]$ .

# %%
# SISTEMA_1_SLIT
import numpy as np
import matplotlib.pyplot as plt

def sistema1(x):
    y = np.zeros_like(x)
    for n in range(1, len(x)):
        y[n] = x[n]/3 + 2*x[n-1] - y[n-1]
    return y

# Señal de prueba
n = np.arange(0, 20)
x = np.ones_like(n)  # escalón unitario
y = sistema1(x)

plt.stem(n, y)
plt.title("Respuesta del Sistema 1")
plt.xlabel("n")
plt.ylabel("y[n]")
plt.grid(True)
plt.show()

# %% [markdown]
# ##SISTEMA 2 - sumatoria no lineal#
# $y[n] = \sum_{k=-\infty}^{n} x^2[k]$

# %%
# SISTEMA 2 - NO ES SLIT
def sistema2(x):
    y = np.zeros_like(x)
    for n in range(len(x)):
        y[n] = np.sum(x[:n+1]**2)
    return y

x = np.ones_like(n)
y = sistema2(x)

# Gráfica
plt.stem(n, y)
plt.title("Respuesta del Sistema 2")
plt.xlabel("n")
plt.ylabel("y[n]")
plt.grid(True)
plt.show()

# %% [markdown]
# # SISTEMA 3 - filtro de mediana sobre ventana de 3 muestras
# $y[n] = \mathrm{median}(x[n-1],\, x[n],\, x[n+1])$

# %%
# SISTEMA 3 - NO ES SLIT
from scipy.signal import medfilt
import numpy as np # Import numpy as it's used later
import matplotlib.pyplot as plt # Import matplotlib as it's used later

def sistema3(x):
    return medfilt(x, kernel_size=3)

x = np.concatenate((np.ones(5), np.zeros(5), np.ones(5)))
y = sistema3(x)

plt.stem(np.arange(len(x)), y)
plt.title("Respuesta del Sistema 3 (Mediana)")
plt.xlabel("n")
plt.ylabel("y[n]")
plt.grid(True)
plt.show()

# %% [markdown]
# #SISTEMA 4 - relación afín en tiempo continuo#
# $y(t) = A \cdot x(t) + B \qquad \text{con } A, B \in \mathbb{R}$

# %%
# SISTEMA 4 - NO ES SLIT
import numpy as np
import matplotlib.pyplot as plt

# Definimos los parámetros del sistema
A = 2
B = 3

# Señal de entrada x(t): por ejemplo, una onda senoidal
t = np.linspace(0, 2*np.pi, 1000)
x = np.sin(t)

# Aplicamos el sistema: y(t) = A * x(t) + B
y = A * x + B

# Graficamos
plt.figure(figsize=(10, 4))
plt.plot(t, x, label='x(t): entrada')
plt.plot(t, y, label='y(t) = A·x(t) + B', linestyle='--')
plt.title("Sistema 4: y(t) = A·x(t) + B")
plt.xlabel("t")
plt.ylabel("Amplitud")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# #**PUNTO 4**
#
# Hallar la salida y[n] de un SLIT ante la entrada x[n]={−15, 5,−3†, 0, 5, 7,−1}, con respuesta al impulso h[n]={1,−2, 0†, 1,−2}, donde n∈{0,±1,±2, . . . ,±N} y n=0 para x[n]†.

# %% [markdown]
# - Dada la respuesta al impulso en tiempo discreto $h[n]\in\mathbb{R},\mathbb{C}$ de un SLIT $\mathsf{H}\{\cdot\},$ la respuesta del sistema $y[n]\in\mathbb{R},\mathbb{C}$ ante la entrada discreta $x[n]\in\mathbb{R},\mathbb{C}$, se puede calcular mediante el operador convolución:

# %% [markdown]
# $$y[n]=x[n]*h[n] = \sum^\infty_{k=-\infty}x[k]h[n-k]$$

# %% [markdown]
# - En general, se cuenta con vectores de tamaño finito, y con sistemas causales, por ende, si $x[n]$ cuenta con $N$ elementos y $h[n]$ con $L$ elementos, la salida $y[n]$ tendra, en el mejor de los casos, $M = N + L - 1$ elementos distintos de 0.

# %% [markdown]
# Se presenta la simulación del cálculo de la salida de un SLIT en tiempo discreto utilizando la respuesta al impulso y la convolución discreta implementando punto a punto el proceso de suma y comparando los resultados con la librería [convolve]

# %% [markdown]
# **Librerias a Importar y configuración interactiva**

# %%
# %matplotlib inline
from ipywidgets import interact #crear graficos interactivos
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Definir señales correctas (conforme al enunciado)**

# %%
# Entrada x[n] y respuesta al impulso h[n]
x = np.array([-15, 5, -3, 0, 5, 7, -1]).reshape(-1, 1)  # n=0 está en índice 2
h = np.array([1, -2, 0, 1, -2]).reshape(-1, 1)          # n=0 está en índice 2

# %% [markdown]
# **Funciones convgraf() y plot_conv()**

# %%
def convgraf(h, x):
    lx = len(x)
    lh = len(h)
    M = lx + lh - 1  # longitud de la salida
    xm = np.zeros((lh, M))  # almacenamiento de x reflejado y desplazado
    ym = np.zeros(M)        # salida final

    # Reflejar x[k] -> x[-k]
    x_flip = np.flip(x, axis=0).flatten()

    for i in range(M):
        # Desplazar x_flip para formar x[k] en n = i
        x_shift = np.zeros(lh)
        for j in range(lh):
            if 0 <= i - j < lx:
                x_shift[j] = x_flip[i - j]
        xm[:, i] = x_shift
        ym[i] = np.dot(x_shift, h.flatten())  # producto punto

    return xm, ym, h

# %% [markdown]
# **Ejecutar la convolución y visualizarla**

# %%
def plot_conv(k, xm, ym, h):
    plt.figure(figsize=(10, 5))

    plt.stem(xm[:, k], markerfmt='+', label='$x[k]$ desplazado')  # x reflejado y desplazado
    plt.stem(h, linefmt='g', markerfmt='.', label='$h[n-k]$')     # h fija
    plt.stem(ym[:k+1], markerfmt='s', linefmt='r', label='$y[n]$ acumulada')  # salida parcial

    plt.title('Proceso de convolución: $y[n] = x[n] * h[n]$', fontsize=14)
    plt.xlabel('n (índice de tiempo discreto)', fontsize=12)
    plt.ylabel('Amplitud', fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=10)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
xm, ym, h_used = convgraf(h, x)

@interact(k=(0, len(ym)-1, 1))
def show_frame(k=0):
    plot_conv(k, xm, ym, h_used)
# Out:
# interactive(children=(IntSlider(value=0, description='k', max=10), Output()), _dom_classes=('widget-interact',…

# %%
# Calcular índice de n=0 en la salida
n0_x = 2  # n=0 en x
n0_h = 2  # n=0 en h
n0_y = n0_x + n0_h  # n=0 en y

# Crear eje temporal para y[n]
n_y = np.arange(-n0_y, len(ym) - n0_y)

# Mostrar resultados
print("Salida completa de la convolución y[n]:\n")
for n_val, y_val in zip(n_y, ym):
    print(f"n = {n_val:>2} --> y[n] = {y_val:>6.1f}")
# Out:
# Salida completa de la convolución y[n]:
#
# n = -4 --> y[n] =   -1.0
# n = -3 --> y[n] =    9.0
# n = -2 --> y[n] =   -9.0
# n = -1 --> y[n] =  -11.0
# n =  0 --> y[n] =    6.0
# n =  1 --> y[n] =    2.0
# n =  2 --> y[n] =  -35.0
# n =  3 --> y[n] =   27.0
# n =  4 --> y[n] =   11.0
# n =  5 --> y[n] =  -25.0
# n =  6 --> y[n] =   30.0

# %% [markdown]
# ### Parte 2: Respuesta al escalón
#
# Para esta parte del ejercicio, se analiza la respuesta del sistema \( s[n] \), dada por:
#
#
# s[n] = {-1,6,-10,3†,1,-10,2,5}
#
#
# donde el valor con el símbolo (†) en el número 3 corresponde al instante ( n = 0 ).
# Este tipo de respuesta puede interpretarse como una **respuesta al escalón unitario**, es decir, cómo responde el sistema cuando la entrada es:
#
#
# u[n] = \begin{cases}
# 1, & n \geq 0 \\
# 0, & n < 0
# \end{cases}
#
#
# La relación entre la respuesta al escalón \( s[n] \) y la respuesta al impulso \( h[n] \) es:
#
# \[
# h[n] = s[n] - s[n-1]
# \]
#
# En esta parte, simplemente analizamos cómo la entrada \( x[n] \) excita un sistema con esta respuesta, usando convolución discreta:
# \[
# y[n] = x[n] * s[n]
# \]
#
# El resultado de esta convolución representa la salida del sistema con entrada \( x[n] \) y una **respuesta escalonada**, no impulsiva.

# %%
# Nueva respuesta al escalón s[n]
s = np.array([-1, 6, -10, 3, 1, -10, 2, 5]).reshape(-1, 1)  # n = 0 en índice 3

# Convolución con la nueva "respuesta al sistema"
def convgraf_step(s, x):
    lx = len(x)
    lh = len(s)
    M = lx + lh - 1
    xm = np.zeros((lh, M))
    ym = np.zeros(M)

    x_flip = np.flip(x, axis=0).flatten()

    for i in range(M):
        x_shift = np.zeros(lh)
        for j in range(lh):
            if 0 <= i - j < lx:
                x_shift[j] = x_flip[i - j]
        xm[:, i] = x_shift
        ym[i] = np.dot(x_shift, s.flatten())

    return xm, ym, s

# Ejecutamos
xm_step, ym_step, s_used = convgraf_step(s, x)

# Visualización paso a paso con etiquetas
def plot_step(k, xm, ym, s):
    plt.figure(figsize=(10, 5))
    plt.stem(xm[:, k], markerfmt='+', label='$x[k]$ desplazado')
    plt.stem(s, linefmt='g', markerfmt='.', label='$s[n-k]$')
    plt.stem(ym[:k+1], markerfmt='s', linefmt='r', label='$y[n]$')
    plt.title('Convolución con respuesta al escalón: $y[n] = x[n] * s[n]$', fontsize=14)
    plt.xlabel('n (índice de tiempo discreto)', fontsize=12)
    plt.ylabel('Amplitud', fontsize=12)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# Widget interactivo
@interact(k=(0, len(ym_step)-1, 1))
def show_step_frame(k=0):
    plot_step(k, xm_step, ym_step, s_used)
# Out:
# interactive(children=(IntSlider(value=0, description='k', max=13), Output()), _dom_classes=('widget-interact',…

# %%
# Índice de n=0 en x[n] y s[n]
n0_x = 2
n0_s = 3
n0_y_step = n0_x + n0_s  # índice de n=0 en la convolución y[n]

# Eje de tiempo asociado a la salida
n_y_step = np.arange(-n0_y_step, len(ym_step) - n0_y_step)

# Mostrar resultados numéricos
print("Salida completa de la convolución con respuesta al escalón s[n]:\n")
for n_val, y_val in zip(n_y_step, ym_step):
    print(f"n = {n_val:>2} --> y[n] = {y_val:>6.1f}")
# Out:
# Salida completa de la convolución con respuesta al escalón s[n]:
#
# n = -5 --> y[n] =    1.0
# n = -4 --> y[n] =  -13.0
# n = -3 --> y[n] =   47.0
# n = -2 --> y[n] =  -43.0
# n = -1 --> y[n] =  -27.0
# n =  0 --> y[n] =    9.0
# n =  1 --> y[n] =    8.0
# n =  2 --> y[n] = -190.0
# n =  3 --> y[n] =  207.0
# n =  4 --> y[n] =   15.0
# n =  5 --> y[n] =  -71.0
# n =  6 --> y[n] =  145.0
# n =  7 --> y[n] =   -5.0
# n =  8 --> y[n] =  -75.0

# %% [markdown]
# #**Punto 5**
# #Sea la senal Gaussiana:
# #Ejercicios realizados en el siguiente link:
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Transformada_Laplace/Taller_Laplace.pdf

# %% [markdown]
# #**Punto 6**
# #Consultar y realizar los ejercicios del cuaderno Definicion transformada de la Laplace.
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Transformada_Laplace/Definition__Transformada__Laplace.ipynb

# %% [markdown]
# #**Punto 7**
# #Consultar y realizar los ejercicios del cuaderno Propiedades basicas transformada de la Laplace.
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Transformada_Laplace/Propiedades.ipynb

# %% [markdown]
# #**Punto 8**
# #Demuestre las siguientes propiedades:
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Transformada_Laplace/Taller_Laplace.pdf

# %% [markdown]
# #**Punto 9**
# #Encuentre la transformada de Laplace, dibuje el esquema de polos y ceros y la region de convergencia:
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Transformada_Laplace/Taller_Laplace.pdf

# %% [markdown]
# #**Punto 10**
# # Consultar y realizar los ejercicios del cuaderno Transforma da inversa de Laplace.
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Transformada_Laplace/Transformada_inversa.ipynb

# %% [markdown]
# #**Punto 11**
# # Consultar y realizar los ejercicios del cuaderno Autofunciones y SLITs..
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Transformada_Laplace/Autofunciones.ipynb
#
#
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/tree/main/2_SLIT

# %% [markdown]
# #**Punto 12**
# # Encuentre la funcion de transferencia en lazo abierto para un circuito RLC serie (entrada tension de alimentacion- salida tension en el capacitor) y un circuito RCL en paralelo
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Transformada_Laplace/Taller_Laplace.pdf

# %% [markdown]
# #**Punto 13**
# Para las funciones de transferencia en lazo abierto encontradas en el punto anterior, encuentre la expresion de la salida en el tiempo para una configuracion en lazo cerrado del sistema, en funcion de R, L y C, para las siguientes entradas:i) impulso, ii) escalon unitario, y iv) rampa. Compruebe los resultados en simulacion sobre Python (utililzando sympy) y grafique la senal de salida para cada caso.
# https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Transformada_Laplace/Taller_Laplace.pdf

# %% [markdown]
# Ahora realizaremos la simulación numérica y graficaremos las salidas para valores de ejemplo de R, L y C. Puedes cambiar estos valores para observar cómo afecta la respuesta del sistema.

# %%
# Realizar simulaciones numéricas y graficar las salidas

# Define valores de ejemplo para R, L, C
R_val = 10
L_val = 1
C_val = 0.1

# Crea un rango de tiempo
tiempo = np.linspace(0, 10, 500)

# Sustituir valores numéricos y convertir las expresiones simbólicas a funciones numéricas
# RLC Serie
get_y_rlc_serie_impulso = sp.lambdify(t, y_rlc_serie_impulso.subs({R: R_val, L: L_val, C: C_val}), 'numpy')
get_y_rlc_serie_escalon = sp.lambdify(t, y_rlc_serie_escalon.subs({R: R_val, L: L_val, C: C_val}), 'numpy')
get_y_rlc_serie_rampa = sp.lambdify(t, y_rlc_serie_rampa.subs({R: R_val, L: L_val, C: C_val}), 'numpy')

# RCL Paralelo
get_y_rcl_paralelo_impulso = sp.lambdify(t, y_rcl_paralelo_impulso.subs({R: R_val, L: L_val, C: C_val}), 'numpy')
get_y_rcl_paralelo_escalon = sp.lambdify(t, y_rcl_paralelo_escalon.subs({R: R_val, L: L_val, C: C_val}), 'numpy')
get_y_rcl_paralelo_rampa = sp.lambdify(t, y_rcl_paralelo_rampa.subs({R: R_val, L: L_val, C: C_val}), 'numpy')


# Calcular los valores de la salida en el tiempo
# RLC Serie
salida_rlc_serie_impulso = get_y_rlc_serie_impulso(tiempo)
salida_rlc_serie_escalon = get_y_rlc_serie_escalon(tiempo)
salida_rlc_serie_rampa = get_y_rlc_serie_rampa(tiempo)

# RCL Paralelo
salida_rcl_paralelo_impulso = get_y_rcl_paralelo_impulso(tiempo)
salida_rcl_paralelo_escalon = get_y_rcl_paralelo_escalon(tiempo)
salida_rcl_paralelo_rampa = get_y_rcl_paralelo_rampa(tiempo)


# Graficar los resultados para el circuito RLC Serie
plt.figure(figsize=(12, 8))
plt.suptitle('Simulación Circuito RLC Serie en Lazo Cerrado', fontsize=16)

plt.subplot(3, 1, 1)
plt.plot(tiempo, salida_rlc_serie_impulso)
plt.title('Respuesta al Impulso (R={}, L={}, C={})'.format(R_val, L_val, C_val))
plt.xlabel('Tiempo (t)')
plt.ylabel('Amplitud')
plt.grid(True)

plt.subplot(3, 1, 2)
plt.plot(tiempo, salida_rlc_serie_escalon)
plt.title('Respuesta al Escalón Unitario (R={}, L={}, C={})'.format(R_val, L_val, C_val))
plt.xlabel('Tiempo (t)')
plt.ylabel('Amplitud')
plt.grid(True)

plt.subplot(3, 1, 3)
plt.plot(tiempo, salida_rlc_serie_rampa)
plt.title('Respuesta a la Rampa (R={}, L={}, C={})'.format(R_val, L_val, C_val))
plt.xlabel('Tiempo (t)')
plt.ylabel('Amplitud')
plt.grid(True)

plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Ajustar layout para el título
plt.show()

# Graficar los resultados para el circuito RCL Paralelo
plt.figure(figsize=(12, 8))
plt.suptitle('Simulación Circuito RCL Paralelo en Lazo Cerrado', fontsize=16)

plt.subplot(3, 1, 1)
plt.plot(tiempo, salida_rcl_paralelo_impulso)
plt.title('Respuesta al Impulso (R={}, L={}, C={})'.format(R_val, L_val, C_val))
plt.xlabel('Tiempo (t)')
plt.ylabel('Amplitud')
plt.grid(True)

plt.subplot(3, 1, 2)
plt.plot(tiempo, salida_rcl_paralelo_escalon)
plt.title('Respuesta al Escalón Unitario (R={}, L={}, C={})'.format(R_val, L_val, C_val))
plt.xlabel('Tiempo (t)')
plt.ylabel('Amplitud')
plt.grid(True)

plt.subplot(3, 1, 3)
plt.plot(tiempo, salida_rcl_paralelo_rampa)
plt.title('Respuesta a la Rampa (R={}, L={}, C={})'.format(R_val, L_val, C_val))
plt.xlabel('Tiempo (t)')
plt.ylabel('Amplitud')
plt.grid(True)

plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # Ajustar layout para el título
plt.show()

# %% [markdown]
# #**Punto 14**
# Utilizando la herramienta Streamlit, genere un dashboard para la simulacion de los sistemas.El usuario podra escoger el tipo de circuito (serie o parale
# lo), el tipo de respuesta (subamortiguado, sobreamortiguado,amortiguamiento crıtico o inestable), el factor de amortigua
# miento (restringido por el dashboard segun sea el caso) y la
#  frecuencia natural. El dashboard debera mostrar el diagrama
#  de bode, diagrama de polos y ceros, respuesta al impulso, al
#  escalon y a la rampa, el tiempo de levantamiento, maximo
#  sobreimpulso, tiempo del maximo sobreimpulso, tiempo de
#  establecimiento y los valores de R, L, C estimados.
#
# #La dashboard en el siguiente link:
#  https://github.com/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Transformada_Laplace/DashboardLaplace_serie_paralelo_tiporespuesta.ipynb
