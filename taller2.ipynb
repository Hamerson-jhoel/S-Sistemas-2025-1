# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/taller2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ejercicio 1

# %% [markdown]
# Series de Fourier (Exponencial, Trigonométrica y Compacta)
#
# Aplicación: Se usan para representar señales periódicas en el tiempo continuo.
# Espectro: Tienen un espectro de frecuencia discreto. Esto significa que la señal está compuesta por una suma de senoides a frecuencias específicas (múltiplos de la frecuencia fundamental).
# Similitudes entre las formas (Exponencial, Trigonométrica y Compacta): Son representaciones equivalentes de la misma serie, solo cambian la forma en que se expresan los coeficientes y las bases (senos/cosenos vs exponenciales complejas).
# Transformada de Fourier
#
# Aplicación: Se usa para representar señales no periódicas en el tiempo continuo.
# Espectro: Tienen un espectro de frecuencia continuo. Esto significa que la señal puede contener componentes en cualquier frecuencia.
# Transformada de Fourier en Tiempo Discreto (DTFT)
#
# Aplicación: Se usa para representar señales no periódicas en el tiempo discreto.
# Espectro: Tienen un espectro de frecuencia continuo (aunque periódico en la frecuencia).
# Transformada Discreta de Fourier (DFT)
#
# Aplicación: Se usa para representar señales periódicas en el tiempo discreto. En la práctica, se usa para analizar señales de tiempo discreto de longitud finita (considerándolas como un período de una señal periódica).
# Espectro: Tienen un espectro de frecuencia discreto.
# Relación con la DTFT: La DFT son muestras del espectro continuo de la DTFT en frecuencias específicas.
# Combinaciones de Espectro y Señal
#
# Señal / Espectro	Continuo	Discreto
# Tiempo Continuo	Transformada Fourier	Serie de Fourier
# Tiempo Discreto	DTFT	DFT
# Algoritmo Fast Fourier Transform (FFT)
#
# ¿Qué es? La FFT no es una transformada nueva, sino un algoritmo eficiente para calcular la Transformada Discreta de Fourier (DFT).
# Utilidad: La utilidad principal de la FFT es reducir drásticamente el costo computacional para calcular la DFT.
# Funcionamiento (En detalle): La FFT se basa en la propiedad de "dividir y conquistar". Descompone el cálculo de la DFT de tamaño N en cálculos de DFTs de tamaño menor (por ejemplo, N/2), y luego combina los resultados. Esto es posible si N es un número compuesto (especialmente si es una potencia de 2). El algoritmo más común es el de Cooley-Tukey. Básicamente, agrupa los términos de la suma de la DFT de una manera inteligente para evitar repetir cálculos.
# Costo Computacional:
# DFT directa: Calcular la DFT directamente requiere aproximadamente O(N²) operaciones (multiplicaciones y sumas), donde N es el número de muestras.
# FFT: El algoritmo FFT (para N que es potencia de 2) requiere aproximadamente O(N log₂ N) operaciones.
# Comparación de Costo: Como puedes ver, O(N log₂ N) crece mucho más lento que O(N²). Para valores grandes de N, la FFT es significativamente más rápida que el cálculo directo de la DFT. Por ejemplo, para N = 1024, N² es aproximadamente un millón, mientras que N log₂ N es aproximadamente 10000, una reducción muy considerable.

# %% [markdown]
# #ejercicio 2

# %% [markdown]
# Para encontrar la función de densidad espectral (transformada de Fourier) de estas señales sin aplicar propiedades, necesitaremos usar la definición general de la Transformada de Fourier:
#
# $$X(j\omega) = \int_{-\infty}^{\infty} x(t) e^{-j\omega t} dt$$$$X(j\omega) = \int_{-\infty}^{\infty} x(t) e^{-j\omega t} dt$$
#
# Donde $x(t)$$x(t)$ es la señal en el dominio del tiempo y $X(j\omega)$$X(j\omega)$ es su transformada de Fourier en el dominio de la frecuencia angular $\omega$$\omega$.
#
# Vamos a abordar cada señal individualmente:
#
# a) $e^{-a|t|}$$e^{-a|t|}$, $a \in \mathbb{R}^+$$a \in \mathbb{R}^+$
#
# Tenemos que dividir la integral en dos partes debido al valor absoluto:
#
# $$X(j\omega) = \int_{-\infty}^{0} e^{-at} e^{-j\omega t} dt + \int_{0}^{\infty} e^{at} e^{-j\omega t} dt$$$$X(j\omega) = \int_{-\infty}^{0} e^{-at} e^{-j\omega t} dt + \int_{0}^{\infty} e^{at} e^{-j\omega t} dt$$
#
# $$X(j\omega) = \int_{-\infty}^{0} e^{-(a+j\omega)t} dt + \int_{0}^{\infty} e^{(a-j\omega)t} dt$$$$X(j\omega) = \int_{-\infty}^{0} e^{-(a+j\omega)t} dt + \int_{0}^{\infty} e^{(a-j\omega)t} dt$$
#
# Ahora, evaluamos las integrales:
#
# Para la primera integral: $$\int_{-\infty}^{0} e^{-(a+j\omega)t} dt = \left[ \frac{e^{-(a+j\omega)t}}{-(a+j\omega)} \right]_{-\infty}^{0} = \frac{e^0}{-(a+j\omega)} - \lim_{t \to -\infty} \frac{e^{-(a+j\omega)t}}{-(a+j\omega)}$$$$\int_{-\infty}^{0} e^{-(a+j\omega)t} dt = \left[ \frac{e^{-(a+j\omega)t}}{-(a+j\omega)} \right]_{-\infty}^{0} = \frac{e^0}{-(a+j\omega)} - \lim_{t \to -\infty} \frac{e^{-(a+j\omega)t}}{-(a+j\omega)}$$
#
# Dado que $a > 0$$a > 0$, $e^{-(a+j\omega)t} \to 0$$e^{-(a+j\omega)t} \to 0$ cuando $t \to -\infty$$t \to -\infty$. $$= \frac{1}{-(a+j\omega)} = \frac{-1}{a+j\omega}$$$$= \frac{1}{-(a+j\omega)} = \frac{-1}{a+j\omega}$$
#
# Para la segunda integral: $$\int_{0}^{\infty} e^{(a-j\omega)t} dt = \left[ \frac{e^{(a-j\omega)t}}{a-j\omega} \right]_{0}^{\infty} = \lim_{t \to \infty} \frac{e^{(a-j\omega)t}}{a-j\omega} - \frac{e^0}{a-j\omega}$$$$\int_{0}^{\infty} e^{(a-j\omega)t} dt = \left[ \frac{e^{(a-j\omega)t}}{a-j\omega} \right]_{0}^{\infty} = \lim_{t \to \infty} \frac{e^{(a-j\omega)t}}{a-j\omega} - \frac{e^0}{a-j\omega}$$
#
# Esta integral diverge a menos que consideremos un enfoque con la transformada bilateral y su región de convergencia, o si estamos tratando con la transformada de Fourier para distribuciones. Sin embargo, si interpretamos la pregunta en el contexto de señales cuya transformada de Fourier existe en el sentido convencional, debemos reconsiderar el planteamiento inicial para $e^{-a|t|}$$e^{-a|t|}$.
#
# La forma correcta de abordar $e^{-a|t|}$$e^{-a|t|}$ es:
#
# $$e^{-a|t|} = \begin{cases} e^{-at} & t \ge 0 \\ e^{at} & t < 0 \end{cases}$$$$e^{-a|t|} = \begin{cases} e^{-at} & t \ge 0 \\ e^{at} & t < 0 \end{cases}$$
#
# Entonces:
#
# $$X(j\omega) = \int_{-\infty}^{0} e^{at} e^{-j\omega t} dt + \int_{0}^{\infty} e^{-at} e^{-j\omega t} dt$$$$X(j\omega) = \int_{-\infty}^{0} e^{at} e^{-j\omega t} dt + \int_{0}^{\infty} e^{-at} e^{-j\omega t} dt$$ $$X(j\omega) = \int_{-\infty}^{0} e^{(a-j\omega)t} dt + \int_{0}^{\infty} e^{-(a+j\omega)t} dt$$$$X(j\omega) = \int_{-\infty}^{0} e^{(a-j\omega)t} dt + \int_{0}^{\infty} e^{-(a+j\omega)t} dt$$
#
# Para la primera integral: $$\int_{-\infty}^{0} e^{(a-j\omega)t} dt = \left[ \frac{e^{(a-j\omega)t}}{a-j\omega} \right]_{-\infty}^{0} = \frac{e^0}{a-j\omega} - \lim_{t \to -\infty} \frac{e^{(a-j\omega)t}}{a-j\omega} = \frac{1}{a-j\omega}$$$$\int_{-\infty}^{0} e^{(a-j\omega)t} dt = \left[ \frac{e^{(a-j\omega)t}}{a-j\omega} \right]_{-\infty}^{0} = \frac{e^0}{a-j\omega} - \lim_{t \to -\infty} \frac{e^{(a-j\omega)t}}{a-j\omega} = \frac{1}{a-j\omega}$$ (Esto converge si $\text{Re}(a-j\omega)t < 0$$\text{Re}(a-j\omega)t < 0$ para $t \to -\infty$$t \to -\infty$, lo cual es cierto ya que $a > 0$$a > 0$).
#
# Para la segunda integral: $$\int_{0}^{\infty} e^{-(a+j\omega)t} dt = \left[ \frac{e^{-(a+j\omega)t}}{-(a+j\omega)} \right]_{0}^{\infty} = \lim_{t \to \infty} \frac{e^{-(a+j\omega)t}}{-(a+j\omega)} - \frac{e^0}{-(a+j\omega)} = 0 - \frac{1}{-(a+j\omega)} = \frac{1}{a+j\omega}$$$$\int_{0}^{\infty} e^{-(a+j\omega)t} dt = \left[ \frac{e^{-(a+j\omega)t}}{-(a+j\omega)} \right]_{0}^{\infty} = \lim_{t \to \infty} \frac{e^{-(a+j\omega)t}}{-(a+j\omega)} - \frac{e^0}{-(a+j\omega)} = 0 - \frac{1}{-(a+j\omega)} = \frac{1}{a+j\omega}$$ (Esto converge si $\text{Re}(a+j\omega)t < 0$$\text{Re}(a+j\omega)t < 0$ para $t \to \infty$$t \to \infty$, lo cual es cierto ya que $a > 0$$a > 0$).
#
# Sumando ambas partes:
#
# $$X(j\omega) = \frac{1}{a-j\omega} + \frac{1}{a+j\omega} = \frac{a+j\omega + a-j\omega}{(a-j\omega)(a+j\omega)} = \frac{2a}{a^2 - (j\omega)^2} = \frac{2a}{a^2 + \omega^2}$$$$X(j\omega) = \frac{1}{a-j\omega} + \frac{1}{a+j\omega} = \frac{a+j\omega + a-j\omega}{(a-j\omega)(a+j\omega)} = \frac{2a}{a^2 - (j\omega)^2} = \frac{2a}{a^2 + \omega^2}$$
#
# b) $\cos(\omega_c t)$$\cos(\omega_c t)$, $\omega_c \in \mathbb{R}$$\omega_c \in \mathbb{R}$
#
# Podemos usar la identidad de Euler: $\cos(\omega_c t) = \frac{e^{j\omega_c t} + e^{-j\omega_c t}}{2}$$\cos(\omega_c t) = \frac{e^{j\omega_c t} + e^{-j\omega_c t}}{2}$.
#
# $$X(j\omega) = \int_{-\infty}^{\infty} \frac{e^{j\omega_c t} + e^{-j\omega_c t}}{2} e^{-j\omega t} dt$$$$X(j\omega) = \int_{-\infty}^{\infty} \frac{e^{j\omega_c t} + e^{-j\omega_c t}}{2} e^{-j\omega t} dt$$ $$X(j\omega) = \frac{1}{2} \int_{-\infty}^{\infty} (e^{j\omega_c t} e^{-j\omega t} + e^{-j\omega_c t} e^{-j\omega t}) dt$$$$X(j\omega) = \frac{1}{2} \int_{-\infty}^{\infty} (e^{j\omega_c t} e^{-j\omega t} + e^{-j\omega_c t} e^{-j\omega t}) dt$$ $$X(j\omega) = \frac{1}{2} \int_{-\infty}^{\infty} (e^{j(\omega_c - \omega)t} + e^{-j(\omega_c + \omega)t}) dt$$$$X(j\omega) = \frac{1}{2} \int_{-\infty}^{\infty} (e^{j(\omega_c - \omega)t} + e^{-j(\omega_c + \omega)t}) dt$$ $$X(j\omega) = \frac{1}{2} \left( \int_{-\infty}^{\infty} e^{j(\omega_c - \omega)t} dt + \int_{-\infty}^{\infty} e^{-j(\omega_c + \omega)t} dt \right)$$$$X(j\omega) = \frac{1}{2} \left( \int_{-\infty}^{\infty} e^{j(\omega_c - \omega)t} dt + \int_{-\infty}^{\infty} e^{-j(\omega_c + \omega)t} dt \right)$$
#
# Sabemos que la transformada de Fourier de $e^{j\omega_0 t}$$e^{j\omega_0 t}$ es $2\pi \delta(\omega - \omega_0)$$2\pi \delta(\omega - \omega_0)$ y la transformada de Fourier de $e^{-j\omega_0 t}$$e^{-j\omega_0 t}$ es $2\pi \delta(\omega + \omega_0)$$2\pi \delta(\omega + \omega_0)$.
#
# Aplicando esto:
#
# $$X(j\omega) = \frac{1}{2} \left( 2\pi \delta(\omega - \omega_c) + 2\pi \delta(\omega + \omega_c) \right)$$$$X(j\omega) = \frac{1}{2} \left( 2\pi \delta(\omega - \omega_c) + 2\pi \delta(\omega + \omega_c) \right)$$ $$X(j\omega) = \pi \delta(\omega - \omega_c) + \pi \delta(\omega + \omega_c)$$$$X(j\omega) = \pi \delta(\omega - \omega_c) + \pi \delta(\omega + \omega_c)$$
#
# c) $\sin(\omega_s t)$$\sin(\omega_s t)$, $\omega_s \in \mathbb{R}$$\omega_s \in \mathbb{R}$
#
# Usamos la identidad de Euler: $\sin(\omega_s t) = \frac{e^{j\omega_s t} - e^{-j\omega_s t}}{2j}$$\sin(\omega_s t) = \frac{e^{j\omega_s t} - e^{-j\omega_s t}}{2j}$.
#
# $$X(j\omega) = \int_{-\infty}^{\infty} \frac{e^{j\omega_s t} - e^{-j\omega_s t}}{2j} e^{-j\omega t} dt$$$$X(j\omega) = \int_{-\infty}^{\infty} \frac{e^{j\omega_s t} - e^{-j\omega_s t}}{2j} e^{-j\omega t} dt$$ $$X(j\omega) = \frac{1}{2j} \int_{-\infty}^{\infty} (e^{j(\omega_s - \omega)t} - e^{-j(\omega_s + \omega)t}) dt$$$$X(j\omega) = \frac{1}{2j} \int_{-\infty}^{\infty} (e^{j(\omega_s - \omega)t} - e^{-j(\omega_s + \omega)t}) dt$$ $$X(j\omega) = \frac{1}{2j} \left( \int_{-\infty}^{\infty} e^{j(\omega_s - \omega)t} dt - \int_{-\infty}^{\infty} e^{-j(\omega_s + \omega)t} dt \right)$$$$X(j\omega) = \frac{1}{2j} \left( \int_{-\infty}^{\infty} e^{j(\omega_s - \omega)t} dt - \int_{-\infty}^{\infty} e^{-j(\omega_s + \omega)t} dt \right)$$
#
# Aplicando las transformadas de Fourier de exponenciales complejas:
#
# $$X(j\omega) = \frac{1}{2j} \left( 2\pi \delta(\omega - \omega_s) - 2\pi \delta(\omega + \omega_s) \right)$$$$X(j\omega) = \frac{1}{2j} \left( 2\pi \delta(\omega - \omega_s) - 2\pi \delta(\omega + \omega_s) \right)$$ $$X(j\omega) = \frac{2\pi}{2j} (\delta(\omega - \omega_s) - \delta(\omega + \omega_s))$$$$X(j\omega) = \frac{2\pi}{2j} (\delta(\omega - \omega_s) - \delta(\omega + \omega_s))$$ $$X(j\omega) = -j\pi (\delta(\omega - \omega_s) - \delta(\omega + \omega_s))$$$$X(j\omega) = -j\pi (\delta(\omega - \omega_s) - \delta(\omega + \omega_s))$$ $$X(j\omega) = j\pi (\delta(\omega + \omega_s) - \delta(\omega - \omega_s))$$$$X(j\omega) = j\pi (\delta(\omega + \omega_s) - \delta(\omega - \omega_s))$$
#
# d) $f(t)\cos(\omega_c t)$$f(t)\cos(\omega_c t)$, $\omega_c \in \mathbb{R}$$\omega_c \in \mathbb{R}$, $f(t) \in \mathbb{R}, \mathbb{C}$$f(t) \in \mathbb{R}, \mathbb{C}$
#
# Este caso requiere el teorema de la modulación en frecuencia, pero la instrucción es no aplicar propiedades. Sin embargo, la transformada de Fourier de un producto en el tiempo es la convolución en la frecuencia (escalada).
#
# Aplicando la definición:
#
# $$X(j\omega) = \int_{-\infty}^{\infty} f(t)\cos(\omega_c t) e^{-j\omega t} dt$$$$X(j\omega) = \int_{-\infty}^{\infty} f(t)\cos(\omega_c t) e^{-j\omega t} dt$$ $$X(j\omega) = \int_{-\infty}^{\infty} f(t) \left(\frac{e^{j\omega_c t} + e^{-j\omega_c t}}{2}\right) e^{-j\omega t} dt$$$$X(j\omega) = \int_{-\infty}^{\infty} f(t) \left(\frac{e^{j\omega_c t} + e^{-j\omega_c t}}{2}\right) e^{-j\omega t} dt$$ $$X(j\omega) = \frac{1}{2} \int_{-\infty}^{\infty} f(t) (e^{j\omega_c t} e^{-j\omega t} + e^{-j\omega_c t} e^{-j\omega t}) dt$$$$X(j\omega) = \frac{1}{2} \int_{-\infty}^{\infty} f(t) (e^{j\omega_c t} e^{-j\omega t} + e^{-j\omega_c t} e^{-j\omega t}) dt$$ $$X(j\omega) = \frac{1}{2} \int_{-\infty}^{\infty} f(t) (e^{-j(\omega - \omega_c)t} + e^{-j(\omega + \omega_c)t}) dt$$$$X(j\omega) = \frac{1}{2} \int_{-\infty}^{\infty} f(t) (e^{-j(\omega - \omega_c)t} + e^{-j(\omega + \omega_c)t}) dt$$ $$X(j\omega) = \frac{1}{2} \left( \int_{-\infty}^{\infty} f(t) e^{-j(\omega - \omega_c)t} dt + \int_{-\infty}^{\infty} f(t) e^{-j(\omega + \omega_c)t} dt \right)$$$$X(j\omega) = \frac{1}{2} \left( \int_{-\infty}^{\infty} f(t) e^{-j(\omega - \omega_c)t} dt + \int_{-\infty}^{\infty} f(t) e^{-j(\omega + \omega_c)t} dt \right)$$
#
# Observamos que $\int_{-\infty}^{\infty} f(t) e^{-j(\omega - \omega_c)t} dt$$\int_{-\infty}^{\infty} f(t) e^{-j(\omega - \omega_c)t} dt$ es la transformada de Fourier de $f(t)$$f(t)$ evaluada en $\omega - \omega_c$$\omega - \omega_c$, es decir, $F(j(\omega - \omega_c))$$F(j(\omega - \omega_c))$. De manera similar, $\int_{-\infty}^{\infty} f(t) e^{-j(\omega + \omega_c)t} dt$$\int_{-\infty}^{\infty} f(t) e^{-j(\omega + \omega_c)t} dt$ es $F(j(\omega + \omega_c))$$F(j(\omega + \omega_c))$.
#
# Por lo tanto:
#
# $$X(j\omega) = \frac{1}{2} (F(j(\omega - \omega_c)) + F(j(\omega + \omega_c)))$$$$X(j\omega) = \frac{1}{2} (F(j(\omega - \omega_c)) + F(j(\omega + \omega_c)))$$
#
# Donde $F(j\omega)$$F(j\omega)$ es la transformada de Fourier de $f(t)$$f(t)$.
#
# e) $e^{-a|t|^2} = e^{-at^2}$$e^{-a|t|^2} = e^{-at^2}$, $a \in \mathbb{R}^+$$a \in \mathbb{R}^+$
#
# $$X(j\omega) = \int_{-\infty}^{\infty} e^{-at^2} e^{-j\omega t} dt$$$$X(j\omega) = \int_{-\infty}^{\infty} e^{-at^2} e^{-j\omega t} dt$$ $$X(j\omega) = \int_{-\infty}^{\infty} e^{-at^2 - j\omega t} dt$$$$X(j\omega) = \int_{-\infty}^{\infty} e^{-at^2 - j\omega t} dt$$
#
# Completamos el cuadrado en el exponente: $$-at^2 - j\omega t = -a \left( t^2 + j\frac{\omega}{a} t \right) = -a \left( t^2 + j\frac{\omega}{a} t + \left(\frac{j\omega}{2a}\right)^2 - \left(\frac{j\omega}{2a}\right)^2 \right)$$$$-at^2 - j\omega t = -a \left( t^2 + j\frac{\omega}{a} t \right) = -a \left( t^2 + j\frac{\omega}{a} t + \left(\frac{j\omega}{2a}\right)^2 - \left(\frac{j\omega}{2a}\right)^2 \right)$$ $$= -a \left( \left(t + j\frac{\omega}{2a}\right)^2 - \frac{\omega^2}{4a^2} \right) = -a \left(t + j\frac{\omega}{2a}\right)^2 + \frac{\omega^2}{4a}$$$$= -a \left( \left(t + j\frac{\omega}{2a}\right)^2 - \frac{\omega^2}{4a^2} \right) = -a \left(t + j\frac{\omega}{2a}\right)^2 + \frac{\omega^2}{4a}$$
#
# Entonces la integral se convierte en: $$X(j\omega) = \int_{-\infty}^{\infty} e^{-a \left(t + j\frac{\omega}{2a}\right)^2 + \frac{\omega^2}{4a}} dt$$$$X(j\omega) = \int_{-\infty}^{\infty} e^{-a \left(t + j\frac{\omega}{2a}\right)^2 + \frac{\omega^2}{4a}} dt$$ $$X(j\omega) = e^{\frac{\omega^2}{4a}} \int_{-\infty}^{\infty} e^{-a \left(t + j\frac{\omega}{2a}\right)^2} dt$$$$X(j\omega) = e^{\frac{\omega^2}{4a}} \int_{-\infty}^{\infty} e^{-a \left(t + j\frac{\omega}{2a}\right)^2} dt$$
#
# Esta integral es de la forma de una integral Gaussiana. La integral Gaussiana general es $\int_{-\infty}^{\infty} e^{-cx^2} dx = \sqrt{\frac{\pi}{c}}$$\int_{-\infty}^{\infty} e^{-cx^2} dx = \sqrt{\frac{\pi}{c}}$. En nuestro caso, la variable de integración es $t$$t$, y tenemos un desplazamiento complejo. Sin embargo, por el teorema de integración de contorno (si las condiciones se cumplen, que es el caso aquí), el desplazamiento complejo no afecta el valor de la integral para la transformada de Fourier.
#
# Sea $\tau = t + j\frac{\omega}{2a}$$\tau = t + j\frac{\omega}{2a}$, entonces $d\tau = dt$$d\tau = dt$. Los límites de integración permanecen de $-\infty$$-\infty$ a $\infty$$\infty$ en el contorno apropiado.
#
# $$X(j\omega) = e^{\frac{\omega^2}{4a}} \int_{-\infty}^{\infty} e^{-a \tau^2} d\tau$$$$X(j\omega) = e^{\frac{\omega^2}{4a}} \int_{-\infty}^{\infty} e^{-a \tau^2} d\tau$$
#
# Aplicando la fórmula de la integral Gaussiana con $c=a$$c=a$:
#
# $$X(j\omega) = e^{\frac{\omega^2}{4a}} \sqrt{\frac{\pi}{a}}$$$$X(j\omega) = e^{\frac{\omega^2}{4a}} \sqrt{\frac{\pi}{a}}$$
#
# f) $A \text{rect}_d(t)$$A \text{rect}_d(t)$, $A, d \in \mathbb{R}$$A, d \in \mathbb{R}$
#
# La función rectangular $\text{rect}_d(t)$$\text{rect}_d(t)$ se define como: $$\text{rect}_d(t) = \begin{cases} 1 & |t| \le d/2 \\ 0 & |t| > d/2 \end{cases}$$$$\text{rect}_d(t) = \begin{cases} 1 & |t| \le d/2 \\ 0 & |t| > d/2 \end{cases}$$
#
# La señal es $A \text{rect}_d(t)$$A \text{rect}_d(t)$. La integral de Fourier será:
#
# $$X(j\omega) = \int_{-\infty}^{\infty} A \text{rect}_d(t) e^{-j\omega t} dt$$$$X(j\omega) = \int_{-\infty}^{\infty} A \text{rect}_d(t) e^{-j\omega t} dt$$
#
# Como la función rectangular es cero fuera del intervalo $[-d/2, d/2]$$[-d/2, d/2]$, la integral se reduce a:
#
# $$X(j\omega) = \int_{-d/2}^{d/2} A \cdot 1 \cdot e^{-j\omega t} dt$$$$X(j\omega) = \int_{-d/2}^{d/2} A \cdot 1 \cdot e^{-j\omega t} dt$$ $$X(j\omega) = A \int_{-d/2}^{d/2} e^{-j\omega t} dt$$$$X(j\omega) = A \int_{-d/2}^{d/2} e^{-j\omega t} dt$$
#
# Ahora evaluamos la integral:
#
# Para $\omega \ne 0$$\omega \ne 0$: $$X(j\omega) = A \left[ \frac{e^{-j\omega t}}{-j\omega} \right]_{-d/2}^{d/2} = A \left( \frac{e^{-j\omega (d/2)}}{-j\omega} - \frac{e^{-j\omega (-d/2)}}{-j\omega} \right)$$$$X(j\omega) = A \left[ \frac{e^{-j\omega t}}{-j\omega} \right]_{-d/2}^{d/2} = A \left( \frac{e^{-j\omega (d/2)}}{-j\omega} - \frac{e^{-j\omega (-d/2)}}{-j\omega} \right)$$ $$X(j\omega) = A \left( \frac{e^{-j\omega d/2} - e^{j\omega d/2}}{-j\omega} \right) = A \left( \frac{-(e^{j\omega d/2} - e^{-j\omega d/2})}{-j\omega} \right)$$$$X(j\omega) = A \left( \frac{e^{-j\omega d/2} - e^{j\omega d/2}}{-j\omega} \right) = A \left( \frac{-(e^{j\omega d/2} - e^{-j\omega d/2})}{-j\omega} \right)$$ $$X(j\omega) = A \left( \frac{e^{j\omega d/2} - e^{-j\omega d/2}}{j\omega} \right)$$$$X(j\omega) = A \left( \frac{e^{j\omega d/2} - e^{-j\omega d/2}}{j\omega} \right)$$
#
# Recordamos la identidad de Euler para el seno: $\sin(x) = \frac{e^{jx} - e^{-jx}}{2j}$$\sin(x) = \frac{e^{jx} - e^{-jx}}{2j}$. Entonces, $e^{j\omega d/2} - e^{-j\omega d/2} = 2j \sin(\omega d/2)$$e^{j\omega d/2} - e^{-j\omega d/2} = 2j \sin(\omega d/2)$.
#
# $$X(j\omega) = A \left( \frac{2j \sin(\omega d/2)}{j\omega} \right) = A \frac{2 \sin(\omega d/2)}{\omega}$$$$X(j\omega) = A \left( \frac{2j \sin(\omega d/2)}{j\omega} \right) = A \frac{2 \sin(\omega d/2)}{\omega}$$
#
# Esta expresión se puede reescribir usando la función sinc normalizada, $\text{sinc}(x) = \frac{\sin(\pi x)}{\pi x}$$\text{sinc}(x) = \frac{\sin(\pi x)}{\pi x}$.
#
# $$X(j\omega) = A \frac{2 \sin(\omega d/2)}{\omega} = A d \frac{2 \sin(\omega d/2)}{\omega d} = A d \frac{\sin(\omega d/2)}{\omega d / 2}$$$$X(j\omega) = A \frac{2 \sin(\omega d/2)}{\omega} = A d \frac{2 \sin(\omega d/2)}{\omega d} = A d \frac{\sin(\omega d/2)}{\omega d / 2}$$
#
# Si usamos la función sinc no normalizada, $\text{sinc}_u(x) = \frac{\sin(x)}{x}$$\text{sinc}_u(x) = \frac{\sin(x)}{x}$:
#
# $$X(j\omega) = A d \text{sinc}_u(\omega d/2)$$$$X(j\omega) = A d \text{sinc}_u(\omega d/2)$$
#
# Para $\omega = 0$$\omega = 0$: Volvemos a la integral: $$X(j0) = A \int_{-d/2}^{d/2} e^{-j(0)t} dt = A \int_{-d/2}^{d/2} 1 dt = A [t]_{-d/2}^{d/2} = A (d/2 - (-d/2)) = A (d/2 + d/2) = Ad$$$$X(j0) = A \int_{-d/2}^{d/2} e^{-j(0)t} dt = A \int_{-d/2}^{d/2} 1 dt = A [t]_{-d/2}^{d/2} = A (d/2 - (-d/2)) = A (d/2 + d/2) = Ad$$
#
# La expresión $A d \frac{\sin(\omega d/2)}{\omega d / 2}$$A d \frac{\sin(\omega d/2)}{\omega d / 2}$ se aproxima a $Ad$$Ad$ cuando $\omega \to 0$$\omega \to 0$ (usando el límite $\lim_{x \to 0} \frac{\sin(x)}{x} = 1$$\lim_{x \to 0} \frac{\sin(x)}{x} = 1$), por lo que la fórmula es consistente.
#
# En resumen, las transformadas de Fourier son:
#
# a) $e^{-a|t|}$$e^{-a|t|}$: $X(j\omega) = \frac{2a}{a^2 + \omega^2}$$X(j\omega) = \frac{2a}{a^2 + \omega^2}$ b) $\cos(\omega_c t)$$\cos(\omega_c t)$: $X(j\omega) = \pi \delta(\omega - \omega_c) + \pi \delta(\omega + \omega_c)$$X(j\omega) = \pi \delta(\omega - \omega_c) + \pi \delta(\omega + \omega_c)$ c) $\sin(\omega_s t)$$\sin(\omega_s t)$: $X(j\omega) = j\pi (\delta(\omega + \omega_s) - \delta(\omega - \omega_s))$$X(j\omega) = j\pi (\delta(\omega + \omega_s) - \delta(\omega - \omega_s))$ d) $f(t)\cos(\omega_c t)$$f(t)\cos(\omega_c t)$: $X(j\omega) = \frac{1}{2} (F(j(\omega - \omega_c)) + F(j(\omega + \omega_c)))$$X(j\omega) = \frac{1}{2} (F(j(\omega - \omega_c)) + F(j(\omega + \omega_c)))$, donde $F(j\omega)$$F(j\omega)$ es la transformada de Fourier de $f(t)$$f(t)$. e) $e^{-at^2}$$e^{-at^2}$: $X(j\omega) = \sqrt{\frac{\pi}{a}} e^{\frac{\omega^2}{4a}}$$X(j\omega) = \sqrt{\frac{\pi}{a}} e^{\frac{\omega^2}{4a}}$ f) $A \text{rect}_d(t)$$A \text{rect}_d(t)$: $X(j\omega) = A d \frac{\sin(\omega d/2)}{\omega d / 2} = A d \text{sinc}_u(\omega d/2)$$X(j\omega) = A d \frac{\sin(\omega d/2)}{\omega d / 2} = A d \text{sinc}_u(\omega d/2)$
#
# He calculado estas transformadas de Fourier utilizando la definición de la transformada, sin aplicar propiedades como linealidad o dualidad directamente sobre los resultados conocidos, aunque para las señales sinusoidales y la modulación, las identidades de Euler y la definición de la transformada de un producto naturalmente llevan a expresiones relacionadas con la transformada de las componentes.
