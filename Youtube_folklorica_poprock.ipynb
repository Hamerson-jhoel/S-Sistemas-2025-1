# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamerson-jhoel/S-Sistemas-2025-1/blob/main/Youtube_folklorica_poprock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#cargar datos desde drive acceso libre
#https://docs.google.com/spreadsheets/d/1d__TtJbs10zkZDSXH6efwKPuKKBLPPQW/edit?usp=sharing&ouid=103591846109822754972&rtpof=true&sd=true
FILEID = "1d__TtJbs10zkZDSXH6efwKPuKKBLPPQW" #"1DxI5wQpqEWksw2BqJnG7n0IgNQ_xByX-"

# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id='$FILEID -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id="$FILEID -O  canciones.xlsx && rm -rf /tmp/cookies.txt
#!unzip -o codigos.zip
# !dir
# Out:
# --2025-06-10 18:30:17--  https://docs.google.com/uc?export=download&confirm=&id=1d__TtJbs10zkZDSXH6efwKPuKKBLPPQW
# Resolving docs.google.com (docs.google.com)... 142.251.16.100, 142.251.16.102, 142.251.16.101, ...
# Connecting to docs.google.com (docs.google.com)|142.251.16.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1d__TtJbs10zkZDSXH6efwKPuKKBLPPQW&export=download [following]
# --2025-06-10 18:30:17--  https://drive.usercontent.google.com/download?id=1d__TtJbs10zkZDSXH6efwKPuKKBLPPQW&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.167.132, 2607:f8b0:4004:c1d::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.167.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10532 (10K) [application/octet-stream]
# Saving to: ‘canciones.xlsx’
#
# canciones.xlsx      100%[===================>]  10.29K  --.-KB/s    in 0s
#
# 2025-06-10 18:30:19 (54.5 MB/s) - ‘canciones.xlsx’ saved [10532/10532]
#
# canciones.xlsx	sample_data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_ = 'canciones.xlsx'#leer archivo xlsx con link, band, type
X  = pd.read_excel(file_)
X#imprimir filas iniciales
# Out:
#                                           link             band        type  \
# 0  https://www.youtube.com/watch?v=UlsVL56r5vc          kjarkas  folklorica
# 1  https://www.youtube.com/watch?v=locPdV3irM0          kjarkas  folklorica
# 2  https://www.youtube.com/watch?v=_NEz5nqRT5k          kjarkas  folklorica
# 3  https://www.youtube.com/watch?v=PZngNEYZouc          kjarkas  folklorica
# 4  https://www.youtube.com/watch?v=6H3QwNrk_WU          kjarkas  folklorica
# 5  https://www.youtube.com/watch?v=IhnOpwOMHgk         la_union    pop_rock
# 6  https://www.youtube.com/watch?v=6bIimzl5NYM        duncan_du    pop_rock
# 7  https://www.youtube.com/watch?v=BRuHGchMrD8  enanitos_verdes    pop_rock
# 8  https://www.youtube.com/watch?v=T_FkEw27XJ0      soda_stereo    pop_rock
# 9  https://www.youtube.com/watch?v=OhXeBoTlCr4             mana    pop_rock
#
#    type_num
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# 5         2
# 6         2
# 7         2
# 8         2
# 9         2

# %%
#instalar librerias necesarias para descargar audios youtube
# !python3 -m pip install --force-reinstall https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
# !pip install soundfile

# Paquete de carga de cookies para el control anti-bots captcha
# !pip install browser-cookie3

import os
import yt_dlp as youtube_dl
import browser_cookie3

try:
    cookies = browser_cookie3.firefox()
except:
    print("No se pueden descargar cookies desde firefox. Intentando Chrome...")
    try:
        cookies = browser_cookie3.chrome()
    except:
        print("No se pueden descargar cookies desde Chrome. Por favor asegúrate de estar logueado en Youtube desde tu navegador.")
        cookies = None

#funcion para descargar mp3 desde youtube
def download_ytvid_as_mp3(video_url,name):
    #video_url = input("enter url of youtube video:")
    options={
        'format':'bestaudio/best',
        'keepvideo':False,
        'outtmpl':f'{name}.mp3',
    }
    if cookies:
        options['cookiefile'] = None
        options['cookiejar'] = cookies;

    with youtube_dl.YoutubeDL(options) as ydl:
        try:
            video_info = ydl.extract_info(video_url, download=False)
            ydl.download([video_info['webpage_url']])
            print("Download complete... {}".format(filename))
        except Exception as e:
            print(f"Error descargando {video_url}: {e}")
# Out:
# Collecting https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
#   Downloading https://github.com/yt-dlp/yt-dlp/archive/master.tar.gz
#      - 2.8 MB 8.9 MB/s 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: yt-dlp
#   Building wheel for yt-dlp (pyproject.toml) ... done
#   Created wheel for yt-dlp: filename=yt_dlp-2025.6.9-py3-none-any.whl size=3014115 sha256=718a5ca3efc879fc65554ef9726bd6169adc02d28d27fb6b3226595d3aa52f62
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xecj4dcv/wheels/2d/79/97/7209650ef73114e0fe0603480da012ad3afacb9cae6b8acd9a
# Successfully built yt-dlp
# Installing collected packages: yt-dlp
# Successfully installed yt-dlp-2025.6.9
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from soundfile) (2.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Collecting browser-cookie3
#   Downloading browser_cookie3-0.20.1-py3-none-any.whl.metadata (713 bytes)
# Collecting lz4 (from browser-cookie3)
#   Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.11/dist-packages (from browser-cookie3) (3.23.0)
# Requirement already satisfied: jeepney in /usr/local/lib/python3.11/dist-packages (from browser-cookie3) (0.9.0)
# Downloading browser_cookie3-0.20.1-py3-none-any.whl (17 kB)
# Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.0 MB/s eta 0:00:00
# Installing collected packages: lz4, browser-cookie3
# Successfully installed browser-cookie3-0.20.1 lz4-4.4.4
# No se pueden descargar cookies desde firefox. Intentando Chrome...
# No se pueden descargar cookies desde Chrome. Por favor asegúrate de estar logueado en Youtube desde tu navegador.

# %%
import subprocess
import os

#crear carpeta con resultados
try:
  os.mkdir('results')
except:
  print("Carpeta results ya existe")

#recorrer excel con videos
N, P = X.shape
Ns = N * 5 #cantidad de segmentos por cancion

for n in range(N):
    print(f"video {n+1} de {N}")
    print(f"link: {X.loc[n,'link']}\n")
    print(f"band: {X.loc[n,'band']}\n")
    print(f"type: {X.loc[n,'type']}\n")
    #ruta video n-th
    name_ = 'results/'+X.loc[n,'band']+"_"+str(n)+"_"+str(X.loc[n,'type_num']) # #video+nombre+tipo de genero musical
    #descargar mp3 desde youtube
    try: # Added try block to catch download errors
        download_ytvid_as_mp3(X.loc[n,'link'],name_)
        #convertir a .wav
        subprocess.call(['ffmpeg','-y', '-i', name_+'.mp3',
                       name_+'.wav'])
    except youtube_dl.utils.DownloadError as e: # Catch the specific DownloadError
        print(f"Skipping video {X.loc[n,'link']} due to download error: {e}") # Print a message and skip
# Out:
# video 1 de 10
# link: https://www.youtube.com/watch?v=UlsVL56r5vc
#
# band: kjarkas
#
# type: folklorica
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UlsVL56r5vc
# [youtube] UlsVL56r5vc: Downloading webpage
# [youtube] UlsVL56r5vc: Downloading tv client config
# [youtube] UlsVL56r5vc: Downloading player fc2a56a5-main
# [youtube] UlsVL56r5vc: Downloading tv player API JSON
# [youtube] UlsVL56r5vc: Downloading ios player API JSON
# [youtube] UlsVL56r5vc: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=UlsVL56r5vc
# [youtube] UlsVL56r5vc: Downloading webpage
# [youtube] UlsVL56r5vc: Downloading tv client config
# [youtube] UlsVL56r5vc: Downloading tv player API JSON
# [youtube] UlsVL56r5vc: Downloading ios player API JSON
# [youtube] UlsVL56r5vc: Downloading m3u8 information
# [info] UlsVL56r5vc: Downloading 1 format(s): 251
# [download] Destination: results/kjarkas_0_1.mp3
# [download] 100% of    3.49MiB in 00:00:00 at 36.29MiB/s
# Error descargando https://www.youtube.com/watch?v=UlsVL56r5vc: name 'filename' is not defined
# video 2 de 10
# link: https://www.youtube.com/watch?v=locPdV3irM0
#
# band: kjarkas
#
# type: folklorica
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=locPdV3irM0
# [youtube] locPdV3irM0: Downloading webpage
# [youtube] locPdV3irM0: Downloading tv client config
# [youtube] locPdV3irM0: Downloading tv player API JSON
# [youtube] locPdV3irM0: Downloading ios player API JSON
# [youtube] locPdV3irM0: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=locPdV3irM0
# [youtube] locPdV3irM0: Downloading webpage
# [youtube] locPdV3irM0: Downloading tv client config
# [youtube] locPdV3irM0: Downloading tv player API JSON
# [youtube] locPdV3irM0: Downloading ios player API JSON
# [youtube] locPdV3irM0: Downloading m3u8 information
# [info] locPdV3irM0: Downloading 1 format(s): 251
# [download] Destination: results/kjarkas_1_1.mp3
# [download] 100% of    3.17MiB in 00:00:00 at 14.72MiB/s
# Error descargando https://www.youtube.com/watch?v=locPdV3irM0: name 'filename' is not defined
# video 3 de 10
# link: https://www.youtube.com/watch?v=_NEz5nqRT5k
#
# band: kjarkas
#
# type: folklorica
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_NEz5nqRT5k
# [youtube] _NEz5nqRT5k: Downloading webpage
# [youtube] _NEz5nqRT5k: Downloading tv client config
# [youtube] _NEz5nqRT5k: Downloading tv player API JSON
# [youtube] _NEz5nqRT5k: Downloading ios player API JSON
# [youtube] _NEz5nqRT5k: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=_NEz5nqRT5k
# [youtube] _NEz5nqRT5k: Downloading webpage
# [youtube] _NEz5nqRT5k: Downloading tv client config
# [youtube] _NEz5nqRT5k: Downloading tv player API JSON
# [youtube] _NEz5nqRT5k: Downloading ios player API JSON
# [youtube] _NEz5nqRT5k: Downloading m3u8 information
# [info] _NEz5nqRT5k: Downloading 1 format(s): 251
# [download] Destination: results/kjarkas_2_1.mp3
# [download] 100% of    2.88MiB in 00:00:00 at 22.60MiB/s
# Error descargando https://www.youtube.com/watch?v=_NEz5nqRT5k: name 'filename' is not defined
# video 4 de 10
# link: https://www.youtube.com/watch?v=PZngNEYZouc
#
# band: kjarkas
#
# type: folklorica
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PZngNEYZouc
# [youtube] PZngNEYZouc: Downloading webpage
# [youtube] PZngNEYZouc: Downloading tv client config
# [youtube] PZngNEYZouc: Downloading tv player API JSON
# [youtube] PZngNEYZouc: Downloading ios player API JSON
# [youtube] PZngNEYZouc: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=PZngNEYZouc
# [youtube] PZngNEYZouc: Downloading webpage
# [youtube] PZngNEYZouc: Downloading tv client config
# [youtube] PZngNEYZouc: Downloading tv player API JSON
# [youtube] PZngNEYZouc: Downloading ios player API JSON
# [youtube] PZngNEYZouc: Downloading m3u8 information
# [info] PZngNEYZouc: Downloading 1 format(s): 251
# [download] Destination: results/kjarkas_3_1.mp3
# [download] 100% of    4.35MiB in 00:00:00 at 29.93MiB/s
# Error descargando https://www.youtube.com/watch?v=PZngNEYZouc: name 'filename' is not defined
# video 5 de 10
# link: https://www.youtube.com/watch?v=6H3QwNrk_WU
#
# band: kjarkas
#
# type: folklorica
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6H3QwNrk_WU
# [youtube] 6H3QwNrk_WU: Downloading webpage
# [youtube] 6H3QwNrk_WU: Downloading tv client config
# [youtube] 6H3QwNrk_WU: Downloading tv player API JSON
# [youtube] 6H3QwNrk_WU: Downloading ios player API JSON
# [youtube] 6H3QwNrk_WU: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6H3QwNrk_WU
# [youtube] 6H3QwNrk_WU: Downloading webpage
# [youtube] 6H3QwNrk_WU: Downloading tv client config
# [youtube] 6H3QwNrk_WU: Downloading tv player API JSON
# [youtube] 6H3QwNrk_WU: Downloading ios player API JSON
# [youtube] 6H3QwNrk_WU: Downloading m3u8 information
# [info] 6H3QwNrk_WU: Downloading 1 format(s): 251
# [download] Destination: results/kjarkas_4_1.mp3
# [download] 100% of    3.99MiB in 00:00:00 at 34.74MiB/s
# Error descargando https://www.youtube.com/watch?v=6H3QwNrk_WU: name 'filename' is not defined
# video 6 de 10
# link: https://www.youtube.com/watch?v=IhnOpwOMHgk
#
# band: la_union
#
# type: pop_rock
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IhnOpwOMHgk
# [youtube] IhnOpwOMHgk: Downloading webpage
# [youtube] IhnOpwOMHgk: Downloading tv client config
# [youtube] IhnOpwOMHgk: Downloading tv player API JSON
# [youtube] IhnOpwOMHgk: Downloading ios player API JSON
# [youtube] IhnOpwOMHgk: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=IhnOpwOMHgk
# [youtube] IhnOpwOMHgk: Downloading webpage
# [youtube] IhnOpwOMHgk: Downloading tv client config
# [youtube] IhnOpwOMHgk: Downloading tv player API JSON
# [youtube] IhnOpwOMHgk: Downloading ios player API JSON
# [youtube] IhnOpwOMHgk: Downloading m3u8 information
# [info] IhnOpwOMHgk: Downloading 1 format(s): 251
# [download] Destination: results/la_union_5_2.mp3
# [download] 100% of    3.84MiB in 00:00:00 at 20.12MiB/s
# Error descargando https://www.youtube.com/watch?v=IhnOpwOMHgk: name 'filename' is not defined
# video 7 de 10
# link: https://www.youtube.com/watch?v=6bIimzl5NYM
#
# band: duncan_du
#
# type: pop_rock
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6bIimzl5NYM
# [youtube] 6bIimzl5NYM: Downloading webpage
# [youtube] 6bIimzl5NYM: Downloading tv client config
# [youtube] 6bIimzl5NYM: Downloading tv player API JSON
# [youtube] 6bIimzl5NYM: Downloading ios player API JSON
# [youtube] 6bIimzl5NYM: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=6bIimzl5NYM
# [youtube] 6bIimzl5NYM: Downloading webpage
# [youtube] 6bIimzl5NYM: Downloading tv client config
# [youtube] 6bIimzl5NYM: Downloading tv player API JSON
# [youtube] 6bIimzl5NYM: Downloading ios player API JSON
# [youtube] 6bIimzl5NYM: Downloading m3u8 information
# [info] 6bIimzl5NYM: Downloading 1 format(s): 251
# [download] Destination: results/duncan_du_6_2.mp3
# [download] 100% of    3.66MiB in 00:00:00 at 36.22MiB/s
# Error descargando https://www.youtube.com/watch?v=6bIimzl5NYM: name 'filename' is not defined
# video 8 de 10
# link: https://www.youtube.com/watch?v=BRuHGchMrD8
#
# band: enanitos_verdes
#
# type: pop_rock
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BRuHGchMrD8
# [youtube] BRuHGchMrD8: Downloading webpage
# [youtube] BRuHGchMrD8: Downloading tv client config
# [youtube] BRuHGchMrD8: Downloading tv player API JSON
# [youtube] BRuHGchMrD8: Downloading ios player API JSON
# [youtube] BRuHGchMrD8: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=BRuHGchMrD8
# [youtube] BRuHGchMrD8: Downloading webpage
# [youtube] BRuHGchMrD8: Downloading tv client config
# [youtube] BRuHGchMrD8: Downloading tv player API JSON
# [youtube] BRuHGchMrD8: Downloading ios player API JSON
# [youtube] BRuHGchMrD8: Downloading m3u8 information
# [info] BRuHGchMrD8: Downloading 1 format(s): 251
# [download] Destination: results/enanitos_verdes_7_2.mp3
# [download] 100% of    3.68MiB in 00:00:00 at 33.68MiB/s
# Error descargando https://www.youtube.com/watch?v=BRuHGchMrD8: name 'filename' is not defined
# video 9 de 10
# link: https://www.youtube.com/watch?v=T_FkEw27XJ0
#
# band: soda_stereo
#
# type: pop_rock
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=T_FkEw27XJ0
# [youtube] T_FkEw27XJ0: Downloading webpage
# [youtube] T_FkEw27XJ0: Downloading tv client config
# [youtube] T_FkEw27XJ0: Downloading tv player API JSON
# [youtube] T_FkEw27XJ0: Downloading ios player API JSON
# [youtube] T_FkEw27XJ0: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=T_FkEw27XJ0
# [youtube] T_FkEw27XJ0: Downloading webpage
# [youtube] T_FkEw27XJ0: Downloading tv client config
# [youtube] T_FkEw27XJ0: Downloading tv player API JSON
# [youtube] T_FkEw27XJ0: Downloading ios player API JSON
# [youtube] T_FkEw27XJ0: Downloading m3u8 information
# [info] T_FkEw27XJ0: Downloading 1 format(s): 251
# [download] Destination: results/soda_stereo_8_2.mp3
# [download] 100% of    3.28MiB in 00:00:00 at 33.40MiB/s
# Error descargando https://www.youtube.com/watch?v=T_FkEw27XJ0: name 'filename' is not defined
# video 10 de 10
# link: https://www.youtube.com/watch?v=OhXeBoTlCr4
#
# band: mana
#
# type: pop_rock
#
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OhXeBoTlCr4
# [youtube] OhXeBoTlCr4: Downloading webpage
# [youtube] OhXeBoTlCr4: Downloading tv client config
# [youtube] OhXeBoTlCr4: Downloading tv player API JSON
# [youtube] OhXeBoTlCr4: Downloading ios player API JSON
# [youtube] OhXeBoTlCr4: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=OhXeBoTlCr4
# [youtube] OhXeBoTlCr4: Downloading webpage
# [youtube] OhXeBoTlCr4: Downloading tv client config
# [youtube] OhXeBoTlCr4: Downloading tv player API JSON
# [youtube] OhXeBoTlCr4: Downloading ios player API JSON
# [youtube] OhXeBoTlCr4: Downloading m3u8 information
# [info] OhXeBoTlCr4: Downloading 1 format(s): 251
# [download] Destination: results/mana_9_2.mp3
# [download] 100% of    4.21MiB in 00:00:00 at 18.99MiB/s
# Error descargando https://www.youtube.com/watch?v=OhXeBoTlCr4: name 'filename' is not defined

# %%
#cargar .wavs y partir audios
#lista archivos .wav
path = 'results/'
wav_files = [f for f in os.listdir(path) if f.endswith('.wav')]
wav_files
# Out:
# ['kjarkas_1_1.wav',
#  'mana_9_2.wav',
#  'soda_stereo_8_2.wav',
#  'kjarkas_0_1.wav',
#  'kjarkas_3_1.wav',
#  'la_union_5_2.wav',
#  'kjarkas_4_1.wav',
#  'enanitos_verdes_7_2.wav',
#  'kjarkas_2_1.wav',
#  'duncan_du_6_2.wav']

# %%
import soundfile as sf # para instalar pip install soundfile
from scipy.signal import resample_poly


#leer archivos y crear np.array audios
fs = 48000
tl = np.array([30,40,50,60,70,80]) #puntos lectura
ts = 5 #t segmento
Ns = len(wav_files)*len(tl) #cantidad segmentos
x_t = np.zeros((Ns,int(ts*fs),2)) #Ns segmentos, cantidad de muestras, 2 canales (stereo)
label = np.zeros((Ns,1)) #vector tipo de genero
type_c = X['type'].unique()
name_c = []
#leer archivos wav
i = 0
for name in wav_files:#lectura audio .wav
    x, fs_i = sf.read(path+name)
    for ti in tl: #segmentos de tiempo
        print(name,'x',x.shape,'fs actual:',fs_i)
        xc = x[int(fs*ti):int(fs*(ti+ts)),:]
        if fs_i < fs:
          # Resample using resample_poly
          gcd = np.gcd(fs, fs_i)
          up = fs // gcd
          down = fs_i // gcd
          xc = resample_poly(x, up=up, down=down)
        x_t[i] = xc
        label[i] = int(name[-5]) #tipo de genero
        name_c += [name[:-6]]
        print(f"{i} lectura: {name}; segundo {ti}:{ti+ts}; tipo música: {type_c[int(label[i])-1]}")
        i+=1
x_t.shape
# Out:
# kjarkas_1_1.wav x (9091200, 2) fs actual: 48000
# 0 lectura: kjarkas_1_1.wav; segundo 30:35; tipo música: folklorica
# kjarkas_1_1.wav x (9091200, 2) fs actual: 48000
# 1 lectura: kjarkas_1_1.wav; segundo 40:45; tipo música: folklorica
# kjarkas_1_1.wav x (9091200, 2) fs actual: 48000
# 2 lectura: kjarkas_1_1.wav; segundo 50:55; tipo música: folklorica
# kjarkas_1_1.wav x (9091200, 2) fs actual: 48000
# 3 lectura: kjarkas_1_1.wav; segundo 60:65; tipo música: folklorica
# kjarkas_1_1.wav x (9091200, 2) fs actual: 48000
# 4 lectura: kjarkas_1_1.wav; segundo 70:75; tipo música: folklorica
# kjarkas_1_1.wav x (9091200, 2) fs actual: 48000
# 5 lectura: kjarkas_1_1.wav; segundo 80:85; tipo música: folklorica
# mana_9_2.wav x (12638709, 2) fs actual: 48000
# 6 lectura: mana_9_2.wav; segundo 30:35; tipo música: pop_rock
# mana_9_2.wav x (12638709, 2) fs actual: 48000
# 7 lectura: mana_9_2.wav; segundo 40:45; tipo música: pop_rock
# mana_9_2.wav x (12638709, 2) fs actual: 48000
# 8 lectura: mana_9_2.wav; segundo 50:55; tipo música: pop_rock
# mana_9_2.wav x (12638709, 2) fs actual: 48000
# 9 lectura: mana_9_2.wav; segundo 60:65; tipo música: pop_rock
# mana_9_2.wav x (12638709, 2) fs actual: 48000
# 10 lectura: mana_9_2.wav; segundo 70:75; tipo música: pop_rock
# mana_9_2.wav x (12638709, 2) fs actual: 48000
# 11 lectura: mana_9_2.wav; segundo 80:85; tipo música: pop_rock
# <ipython-input-6-3323026262>:30: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print(f"{i} lectura: {name}; segundo {ti}:{ti+ts}; tipo música: {type_c[int(label[i])-1]}")
# soda_stereo_8_2.wav x (10082291, 2) fs actual: 48000
# 12 lectura: soda_stereo_8_2.wav; segundo 30:35; tipo música: pop_rock
# soda_stereo_8_2.wav x (10082291, 2) fs actual: 48000
# 13 lectura: soda_stereo_8_2.wav; segundo 40:45; tipo música: pop_rock
# soda_stereo_8_2.wav x (10082291, 2) fs actual: 48000
# 14 lectura: soda_stereo_8_2.wav; segundo 50:55; tipo música: pop_rock
# soda_stereo_8_2.wav x (10082291, 2) fs actual: 48000
# 15 lectura: soda_stereo_8_2.wav; segundo 60:65; tipo música: pop_rock
# soda_stereo_8_2.wav x (10082291, 2) fs actual: 48000
# 16 lectura: soda_stereo_8_2.wav; segundo 70:75; tipo música: pop_rock
# soda_stereo_8_2.wav x (10082291, 2) fs actual: 48000
# 17 lectura: soda_stereo_8_2.wav; segundo 80:85; tipo música: pop_rock
# kjarkas_0_1.wav x (10049831, 2) fs actual: 48000
# 18 lectura: kjarkas_0_1.wav; segundo 30:35; tipo música: folklorica
# kjarkas_0_1.wav x (10049831, 2) fs actual: 48000
# 19 lectura: kjarkas_0_1.wav; segundo 40:45; tipo música: folklorica
# kjarkas_0_1.wav x (10049831, 2) fs actual: 48000
# 20 lectura: kjarkas_0_1.wav; segundo 50:55; tipo música: folklorica
# kjarkas_0_1.wav x (10049831, 2) fs actual: 48000
# 21 lectura: kjarkas_0_1.wav; segundo 60:65; tipo música: folklorica
# kjarkas_0_1.wav x (10049831, 2) fs actual: 48000
# 22 lectura: kjarkas_0_1.wav; segundo 70:75; tipo música: folklorica
# kjarkas_0_1.wav x (10049831, 2) fs actual: 48000
# 23 lectura: kjarkas_0_1.wav; segundo 80:85; tipo música: folklorica
# kjarkas_3_1.wav x (12751034, 2) fs actual: 48000
# 24 lectura: kjarkas_3_1.wav; segundo 30:35; tipo música: folklorica
# kjarkas_3_1.wav x (12751034, 2) fs actual: 48000
# 25 lectura: kjarkas_3_1.wav; segundo 40:45; tipo música: folklorica
# kjarkas_3_1.wav x (12751034, 2) fs actual: 48000
# 26 lectura: kjarkas_3_1.wav; segundo 50:55; tipo música: folklorica
# kjarkas_3_1.wav x (12751034, 2) fs actual: 48000
# 27 lectura: kjarkas_3_1.wav; segundo 60:65; tipo música: folklorica
# kjarkas_3_1.wav x (12751034, 2) fs actual: 48000
# 28 lectura: kjarkas_3_1.wav; segundo 70:75; tipo música: folklorica
# kjarkas_3_1.wav x (12751034, 2) fs actual: 48000
# 29 lectura: kjarkas_3_1.wav; segundo 80:85; tipo música: folklorica
# la_union_5_2.wav x (11196800, 2) fs actual: 48000
# 30 lectura: la_union_5_2.wav; segundo 30:35; tipo música: pop_rock
# la_union_5_2.wav x (11196800, 2) fs actual: 48000
# 31 lectura: la_union_5_2.wav; segundo 40:45; tipo música: pop_rock
# la_union_5_2.wav x (11196800, 2) fs actual: 48000
# 32 lectura: la_union_5_2.wav; segundo 50:55; tipo música: pop_rock
# la_union_5_2.wav x (11196800, 2) fs actual: 48000
# 33 lectura: la_union_5_2.wav; segundo 60:65; tipo música: pop_rock
# la_union_5_2.wav x (11196800, 2) fs actual: 48000
# 34 lectura: la_union_5_2.wav; segundo 70:75; tipo música: pop_rock
# la_union_5_2.wav x (11196800, 2) fs actual: 48000
# 35 lectura: la_union_5_2.wav; segundo 80:85; tipo música: pop_rock
# kjarkas_4_1.wav x (11834933, 2) fs actual: 48000
# 36 lectura: kjarkas_4_1.wav; segundo 30:35; tipo música: folklorica
# kjarkas_4_1.wav x (11834933, 2) fs actual: 48000
# 37 lectura: kjarkas_4_1.wav; segundo 40:45; tipo música: folklorica
# kjarkas_4_1.wav x (11834933, 2) fs actual: 48000
# 38 lectura: kjarkas_4_1.wav; segundo 50:55; tipo música: folklorica
# kjarkas_4_1.wav x (11834933, 2) fs actual: 48000
# 39 lectura: kjarkas_4_1.wav; segundo 60:65; tipo música: folklorica
# kjarkas_4_1.wav x (11834933, 2) fs actual: 48000
# 40 lectura: kjarkas_4_1.wav; segundo 70:75; tipo música: folklorica
# kjarkas_4_1.wav x (11834933, 2) fs actual: 48000
# 41 lectura: kjarkas_4_1.wav; segundo 80:85; tipo música: folklorica
# enanitos_verdes_7_2.wav x (10666880, 2) fs actual: 48000
# 42 lectura: enanitos_verdes_7_2.wav; segundo 30:35; tipo música: pop_rock
# enanitos_verdes_7_2.wav x (10666880, 2) fs actual: 48000
# 43 lectura: enanitos_verdes_7_2.wav; segundo 40:45; tipo música: pop_rock
# enanitos_verdes_7_2.wav x (10666880, 2) fs actual: 48000
# 44 lectura: enanitos_verdes_7_2.wav; segundo 50:55; tipo música: pop_rock
# enanitos_verdes_7_2.wav x (10666880, 2) fs actual: 48000
# 45 lectura: enanitos_verdes_7_2.wav; segundo 60:65; tipo música: pop_rock
# enanitos_verdes_7_2.wav x (10666880, 2) fs actual: 48000
# 46 lectura: enanitos_verdes_7_2.wav; segundo 70:75; tipo música: pop_rock
# enanitos_verdes_7_2.wav x (10666880, 2) fs actual: 48000
# 47 lectura: enanitos_verdes_7_2.wav; segundo 80:85; tipo música: pop_rock
# kjarkas_2_1.wav x (8769880, 2) fs actual: 48000
# 48 lectura: kjarkas_2_1.wav; segundo 30:35; tipo música: folklorica
# kjarkas_2_1.wav x (8769880, 2) fs actual: 48000
# 49 lectura: kjarkas_2_1.wav; segundo 40:45; tipo música: folklorica
# kjarkas_2_1.wav x (8769880, 2) fs actual: 48000
# 50 lectura: kjarkas_2_1.wav; segundo 50:55; tipo música: folklorica
# kjarkas_2_1.wav x (8769880, 2) fs actual: 48000
# 51 lectura: kjarkas_2_1.wav; segundo 60:65; tipo música: folklorica
# kjarkas_2_1.wav x (8769880, 2) fs actual: 48000
# 52 lectura: kjarkas_2_1.wav; segundo 70:75; tipo música: folklorica
# kjarkas_2_1.wav x (8769880, 2) fs actual: 48000
# 53 lectura: kjarkas_2_1.wav; segundo 80:85; tipo música: folklorica
# duncan_du_6_2.wav x (11254805, 2) fs actual: 48000
# 54 lectura: duncan_du_6_2.wav; segundo 30:35; tipo música: pop_rock
# duncan_du_6_2.wav x (11254805, 2) fs actual: 48000
# 55 lectura: duncan_du_6_2.wav; segundo 40:45; tipo música: pop_rock
# duncan_du_6_2.wav x (11254805, 2) fs actual: 48000
# 56 lectura: duncan_du_6_2.wav; segundo 50:55; tipo música: pop_rock
# duncan_du_6_2.wav x (11254805, 2) fs actual: 48000
# 57 lectura: duncan_du_6_2.wav; segundo 60:65; tipo música: pop_rock
# duncan_du_6_2.wav x (11254805, 2) fs actual: 48000
# 58 lectura: duncan_du_6_2.wav; segundo 70:75; tipo música: pop_rock
# duncan_du_6_2.wav x (11254805, 2) fs actual: 48000
# 59 lectura: duncan_du_6_2.wav; segundo 80:85; tipo música: pop_rock
# (60, 240000, 2)

# %%
from IPython.display import Audio #reproducir segmento
i = 49
Audio(x_t[i].T,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#calculo de fourier
vf = np.fft.rfftfreq(x_t.shape[1],1/fs) #calculo vector de frecuencias
Xw = np.fft.rfft(x_t,axis=1).mean(axis=-1) #transformada rapida de Fourier para señal Real a lo largo del tiempo (axis=1) y se promedian los dos canales
Xw.shape
# Out:
# (60, 120001)

# %%
#grafica tiempo y fourier
plt.plot(np.arange(0,ts,1/fs),x_t.mean(axis=-1).T) #se promedian los dos canales stereo
plt.xlabel('t[s]')
plt.ylabel('x(t)')
plt.show()

# %%
plt.plot(vf,abs(Xw).T)
plt.xlabel('f[Hz]')
plt.ylabel('|X(f)|')
plt.show()

# %%
#se normalizan espectros entre 0 y 1 para evitar inconsistencias por ampliltudes máximas
from sklearn.preprocessing import MinMaxScaler
sca = MinMaxScaler()
Xw_ = sca.fit_transform(abs(Xw).T).T

plt.plot(vf,Xw_.T)
plt.xlabel('f[Hz]')
plt.ylabel('|X(f)|')
plt.show()

#en dB
plt.plot(vf,(20*np.log10(Xw_+1e-10)).T) # se suma 1e-10 para evitar discontinuidad del log
plt.xlabel('f[Hz]')
plt.ylabel('|X(f)| dB')
plt.show()

# %% [markdown]
# **Nota**: Generalmente el espectro se presenta en [decibeles [dB]](https://es.wikipedia.org/wiki/Decibelio)

# %% [markdown]
# ## Visualización de los datos en 2D

# %%
from umap import UMAP
#visualización de datos
n_neighbors = int(2*np.sqrt(Xw_.shape[0]))
sca_ = MinMaxScaler()

red_ = UMAP(n_components=2,n_neighbors=n_neighbors)
X_2D = sca_.fit_transform(red_.fit_transform(Xw_))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(

# %%
#graficar separabilidad 2D
plt.scatter(X_2D[:,0],X_2D[:,1],c=label)
plt.colorbar()
plt.show()

color_ = ["b","y"]
#nombre cancion
plt.scatter(X_2D[:,0],X_2D[:,1],c=label,s=1)
for i, tex in enumerate(name_c):
    #print(f"{i} {tex}")
    plt.text(X_2D[i,0]*1.025,X_2D[i,1]*1.025, tex[:-2]+"_"+str(i), fontsize=6,color=color_[int(label[i]-1)])

plt.xlim([-0.1,1.1])
plt.ylim([-0.1,1.1])
plt.show()
# Out:
# <ipython-input-13-2468643273>:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.text(X_2D[i,0]*1.025,X_2D[i,1]*1.025, tex[:-2]+"_"+str(i), fontsize=6,color=color_[int(label[i]-1)])

# %%
#reproducir audio
i = 55
Audio(x_t[i].T,rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Predicción del género musical sobre espectro de Fourier

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# Crear una instancia del clasificador RandomForest
model = KNeighborsClassifier(n_neighbors=5)

# Realizar la validación cruzada
# Xw_ son tus características y label son tus etiquetas
# cv define el número folds para la validación cruzada
scores = cross_val_score(model, Xw_, label.ravel(), cv=5,scoring='accuracy')

# Imprimir los resultados de la validación cruzada
print("Acierto para cada Fold:", scores)
print("Acierto promedio:", scores.mean())
print("Desviación estándar del Acierto:", scores.std())

#entrenar modelo para predecir nuevas canciones
model.fit(Xw_, label.ravel())
# Out:
# Acierto para cada Fold: [0.66666667 0.58333333 0.66666667 0.83333333 0.83333333]
# Acierto promedio: 0.7166666666666667
# Desviación estándar del Acierto: 0.10000000000000002
# KNeighborsClassifier()

# %%
import joblib
#guardar modelo
try:
  os.mkdir('modelo')
except:
  print("Carpeta modelo ya existe")

filename_ = 'modelo/folklorica_vs_poprock'
model_ ={'Xw_':Xw_, 'label' : label, 'name_c' : name_c, 'vf':vf,'fs':fs, 'modelo':model,'type':X['type'].unique()}
joblib.dump(model_,filename_+".pkl")
# Out:
# ['modelo/folklorica_vs_poprock.pkl']

# %%
#descargar modelo
#guardar resultados
from google.colab import files
from datetime import date, datetime
import shutil
#guardar resultados
namefile = str(datetime.now().strftime("%Y_%m_%d_%H_%M_%d"))+'modelo'
shutil.make_archive(namefile, 'zip', 'modelo')
files.download(namefile+'.zip')

#el archivo .zip puede cargarse en drive y utilizarse en otro cuaderno para detectar género musical de nuevos segmentos

# %% [markdown]
# # Para una nueva canción

# %%
#cargar modelo
my_model_loaded = joblib.load(filename_+".pkl")
my_model_loaded.keys()
# Out:
# dict_keys(['Xw_', 'label', 'name_c', 'vf', 'fs', 'modelo', 'type'])

# %%
#evaluar para un segmento en fft normalizado

pred_ = my_model_loaded['modelo'].predict(Xw_[0].reshape(1,-1))[0]
print('Etiqueta estimada: ',my_model_loaded['type'][int(pred_-1)])
print('Etiqueta orignal: ',my_model_loaded['type'][int(my_model_loaded['label'][0][0])-1])
# Out:
# Etiqueta estimada:  folklorica
# Etiqueta orignal:  folklorica
